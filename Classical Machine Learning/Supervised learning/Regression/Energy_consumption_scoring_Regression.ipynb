# %% [markdown]
# Прогнозирование вероятности пожара на основе характеристик зданий, выявление проблемных районов и повышения эффективности борьбы с лесными пожарами.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Загрузим данные из датасета

# %%
df = pd.read_csv(r"C:\Users\mmd28\OneDrive\Рабочий стол\Academic potfolio\Classical Machine Learning\Supervised learning\Regression\Data\09_Energy_and_Water_Data_Disclosure_for_Local_Law_84_2017__Data_for_Calendar_Year_2016_.csv")

# %%
df.head()
# Out:
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# ...

# %%
df.columns
# Out:
# Index(['Order', 'Property Id', 'Property Name', 'Parent Property Id',
#        'Parent Property Name', 'BBL - 10 digits',
#        'NYC Borough, Block and Lot (BBL) self-reported',
#        'NYC Building Identification Number (BIN)', 'Address 1 (self-reported)',
#        'Address 2', 'Postal Code', 'Street Number', 'Street Name', 'Borough',
#        'DOF Gross Floor Area', 'Primary Property Type - Self Selected',
#        'List of All Property Use Types at Property',
#        'Largest Property Use Type',
#        'Largest Property Use Type - Gross Floor Area (ft²)',
#        '2nd Largest Property Use Type',
#        '2nd Largest Property Use - Gross Floor Area (ft²)',
#        '3rd Largest Property Use Type',
#        '3rd Largest Property Use Type - Gross Floor Area (ft²)', 'Year Built',
#        'Number of Buildings - Self-reported', 'Occupancy',
#        'Metered Areas (Energy)', 'Metered Areas  (Water)', 'ENERGY STAR Score',
# ...

# %%
df.isnull().sum()
# Out:
# Order                                                            0
# Property Id                                                      0
# Property Name                                                    0
# Parent Property Id                                               0
# Parent Property Name                                             0
# BBL - 10 digits                                                 11
# NYC Borough, Block and Lot (BBL) self-reported                   0
# NYC Building Identification Number (BIN)                         0
# Address 1 (self-reported)                                        0
# Address 2                                                        0
# Postal Code                                                      0
# Street Number                                                  124
# Street Name                                                    122
# Borough                                                        118
# ...

# %% [markdown]
# Пропуски в числовых столбцах:
#
# BBL - 10 digits (11 пропусков)
# Street Number (124 пропуска)
# Street Name (122 пропуска)
# Borough, DOF Gross Floor Area, Water Required? (по 118 пропусков)
# Latitude, Longitude, Community Board, Council District, Census Tract, NTA (2263 пропуска)
# Могут быть важными для дальнейшего анализа: Latitude, Longitude, Community Board, Council District, Census Tract, NTA - пропуски в этих столбцах могут означать отсутствие географической информации для некоторых объектов. Пропуски в Street Name и Street Number также могут быть важными для геолокации, если это требуется для анализа.
#
# Пропуски в категориальных столбцах:
#
# DOF Benchmarking Submission Status (30 пропусков)
# Пропуски в этих столбцах могут указывать на отсутствие данных по выполнению стандартов для некоторых объектов.
